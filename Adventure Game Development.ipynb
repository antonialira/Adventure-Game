# %%
"""
# Game Introduction
This game is based on the movie "Jumanji, Welcome to the Jungle". 
First, you'll need to choose a character and then play 3 levels to complete the game.
To complete the game, the player should write "Jumanji" in the last level as mentioned after choosing a character. 
The skills of each character don't influence the development of the levels of the game. 
Also, is not required to know the movie. Players can use their common sense. 
"""

import random

input(prompt = "<Press enter to begin>\n")

# Pre-start of the game
def pre_start(): 
    print("""How do you want your character to be chosen?
        1. By myself
        2. Randomly""") # Players decide to chose their own characters or not 
    
    answer_0 = input(prompt = " \n") 
    answer_0 = answer_0.lower() # Avoid sensitivity errors 
    
    if "1" in answer_0 or "me" in answer_0 or "i" in answer_0 or "myself" in answer_0:
        print("""Plese select a character
            1. Ruby Roundhouse (Killer of men)
            2. Jefferson Seaplane McDonough (Pilot Rascal)
            3. Franklin 'Mouse' Finbar (Zoology Expert)
            4. Dr. Smolder Bravestone (Archaeologist Explorer)
            5. Prof. Shelly Oberon (Cartographer Curvy Genius)""") # Players choose a character of their preference
    
        answer_1 = input(prompt = "Write the NAME of your character: \n") # Players write their choice 
        answer_1 = answer_1.capitalize() # Avoid sensitivity errors 
    
        if "Ruby" in answer_1 or "Roundhouse" in answer_1:
            print("Good Choice!") # Congratulates the player for his/her choice
            print()
    
        elif "Jefferson" in answer_1 or "Seaplane" in answer_1 or "McDonough" in answer_1:
            print("Good Choice!") 
            print()

        elif "Franklin" in answer_1 or "Mouse" in answer_1 or "Finbar" in answer_1:
            print("Good Choice!")
            print()

        elif "Dr." in answer_1 or "Smolder" in answer_1 or "Bravestone" in answer_1:
            print("Good Choice!") 
            print()

        elif "Prof." in answer_1 or "Shelly" in answer_1 or "Oberon"in answer_1:
            print("Good Choice!")
            print()

        else:
            print("Invalid name. Please try again.")
            pre_start() # Brings us back to the beginning to try again
            print()
            
        print(f"""Welcome to Jumanji {answer_1}.
        You must use your complementary skills to return the jewel to the jaguar 
        statue and break the curse. 
        *REMEMBER* To leave the game you must save Jumanji and write its name.""") # Official welcome to the game 
        input(prompt = "<Press enter to continue>\n")
        level_1() # This moves us to level_1
            
    elif "2" in answer_0 or "random" in answer_0:
        character_list = ["Ruby Roundhouse", "Jefferson Seaplane McDonough", 
                          "Franklin 'Mouse' Finbar", "Dr. Smolder Bravestone",
                          "Prof. Shelly Oberon"] # List of characters
        
        print("Your character is:") 
        answer_01 = random.choice(character_list) # The game decides a random character
        print(answer_01)
        
        print()
        
        print(f"""Welcome to Jumanji {answer_01}.
        You must use your complementary skills to return the jewel to the jaguar 
        statue and break the curse. 
        *REMEMBER* To leave the game you must save Jumanji and write its name.""") # Official welcome to the game
        input(prompt = "<Press enter to continue>\n")
        level_1()
        
        
    else:
        print("Invalid answer. Please try again.")
        pre_start() # Brings us back to the beginning to try again
        print()
    
# Start of the game
def level_1():  
    print("""
    Starting the game, you see some people approaching on a motorcycle. You ...
        1. run for your life.
        2. wait for them to say hi.
        3. use your weapons to fight them.
        
    *You can also write "random" so that an answer is randomly chosen to you""") # First question
        
    answer_2 = input(prompt = " \n") # Players answer their choice: number or words
    answer_2 = answer_2.lower()
    
    if "1" in answer_2 or "run" in answer_2 or "life" in answer_2:
        print("Awesome work! Keep going ")
        level_2() # This moves us to level_2
        
    elif "2" in answer_2 or "wait" in answer_2:
        print("oops! try that again")
        level_1() # Brings us back to level_1 to try again
    
    elif "3" in answer_2 or "use" in answer_2 or "wapons" in answer_2:
        print("oops! try that again")
        level_1() 
        
    elif "random" in answer_2:
        answer2_list = ["run for your life", 
                        "wait for them to say hi",
                        "use your weapons to fight them"] # List of possible answers 
        
        print("Your random answer is:") 
        answer_02 = random.choice(answer2_list) # The game decides a random answer
        print(answer_02)
        
        if "run for your life" in answer_02:    
            print("You were lucky! Keep going") # random answer is correct
            print()
            level_2()
            
        elif "wait for them to say hi" in answer_02:
            print("...but is incorrect. Try that again") # random answer is incorrect
            level_1()
            
        elif "use your weapons to fight them" in answer_02:
            print("...but is incorrect. Try that again") # random answer is incorrect
            level_1()
            
        else:
            print("Something went wrong, try again.")
            level_1()
    
    else:
        print("Invalid entry. Please try again.") # Incorrect answer, back to level_1  
        level_1()
        
def level_2():
    print("""Now, you find yourself in a cave full of obstacles. How do you do to overcome them?
        1. You trust that you can do it by yourself.
        2. You run across without stopping.
        3. You accept the help of another character of the game.
        
        * You can also write "random" so that an answer is randomly chosen to you""") # Second question
     
    answer_3 = input(prompt = " \n") # Players answer their choice: number or words
    answer_3 = answer_3.lower()
    
    if answer_3 == "1" or "trust" in answer_3 or "yourself" in answer_3 or "myself" in answer_3:
        print("Oops! try that again.")
        level_2() # Brings us back to level_2 to try again
    
    elif answer_3 == "2"  or "run" in answer_3:
        print("Oops! try that again.")
        level_2()
    
    elif answer_3 == "3" or "accept" in answer_3 or "help" in answer_3:
        print("Good choice!, you are almost there.")
        level_3() # This moves us to level_3
        
    elif "random" in answer_3:
        answer3_list = ["You trust that you can do it by yourself", 
                        "You run across without stopping",
                        "You accept the help of another character of the game"] # List of possible answers 
        
        print("Your random answer is:") 
        answer_03 = random.choice(answer3_list) # The game decides a random answer
        print(answer_03)
        
        if "You trust that you can do it by yourself" in answer_03:    
            print("...but is incorrect. Try that again") # random answer is incorrect
            print()
            level_2()
            
        elif "You run across without stopping" in answer_03:
            print("...but is incorrect. Try that again") # random answer is incorrect
            level_2()
            
        elif "You accept the help of another character of the game" in answer_03:
            print("And it's correct! You are almost there") # random answer is correct
            level_3()
            
        else:
            print("Something went wrong, try again.")
            level_2()
    
    else:
        print("Invalid entry. Please try again.") # Incorrect answer, back to level_2  
        level_2()

def level_3():
    print("""Now that you managed to get out, you can see the jaguar statue in the distance. 
    What do you do to get there?
        1. You walk 30mi.
        2. You run.
        3. You use a motorcycle that you gained fighting a bad guy.""") # Third question 
    
    answer_4 = input(prompt = " \n") # Players answer their choice: number or words
    answer_4 = answer_4.lower()
    
    if answer_4 == "1" or "walk 30mi" in answer_4:
        print("You almost got it, try again")
        level_3() # Brings us back to level_3 to try again
    
    elif answer_4 == "2" or "run" in answer_4:
        print("You almost got it, try again")
        level_3()
    
    elif answer_4 == "3" or "motorcycle" in answer_4:
        print("Congratulations! You made it to the top of the jaguar statue")
        end() # This moves us to the final level
        
    elif "random" in answer_4:
        answer4_list = ["You walk 30mi", 
                        "You run",
                        "You use a motorcycle that you gained fighting a bad guy"] # List of possible answers 
        
        print("Your random answer is:") 
        answer_04 = random.choice(answer4_list) # The game decides a random answer
        print(answer_04)
        
        if "You walk 30mi" in answer_04:    
            print("...but is incorrect. Try that again") # random answer is incorrect
            print()
            level_3()
            
        elif "You run" in answer_04:
            print("...but is incorrect. Try that again") # random answer is incorrect
            level_3()
            
        elif "You use a motorcycle that you gained fighting a bad guy" in answer_04:
            print("And it's correct! You made it to the top of the jaguar statue") # random answer is correct
            end()
            
        else:
            print("Something went wrong, try again.")
            level_3()
    
    else:
        print("Invalid entry. Please try again.") # Incorrect answer, back to level_3  
        level_3()

# End of the game
def end():
    answer_5 = input(prompt = "Enter your answer to leave the game \n") # Last question

    answer_5 = answer_5.capitalize()
    
    while answer_5 != "Jumanji":   
        try:
            answer_5 = str(answer_5) # Players can try their answer 
        except:
            print("This answer should be one word")
            
        if "Jumanji" in answer_5 or "jumanji" in answer_5: # Correct answer, players can exit the game
            print("""Congratulations!! You saved Jumanji""")
            break 
            
        else:
            fail() # Incorrect answer, players lose the game
            break

def fail():
    print("Sorry, you lost! Game Over") 
    
pre_start()
